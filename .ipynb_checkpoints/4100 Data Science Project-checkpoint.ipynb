# %%
branch?

# %% [markdown]
# Twitter Fingers == Trigger Fingers: A Look at Gun Violence

# %% [markdown]
# We have to first extract the sources from complete_project_dataset, then get the text from it

# %%
import pandas as pd
from bs4 import BeautifulSoup
import socket
import urllib.request
#reads in complete project data
gunviolencedataset = pd.read_csv("complete_project_dataset")
sourceurl = gunviolencedataset["Source"]

#sourceurl[15]

# %% [markdown]
# The function that takes the source url, goes to the url, reads in the text from that site. Currently has a break in the last part so I can experiment with finding things in the html file.

# %%
def getsourcetext(urlseries):
    #initialize beautifulsoup
    soup = BeautifulSoup('''<html> empty </html>''', 'html.parser')
    timeout = 10
    socket.setdefaulttimeout(timeout)
    #textfile = open("all text", "w+",  encoding="utf-8")
    counter = 0
    for k in urlseries:
        print(counter)
        counter = counter + 1
        # here we actually access the website
        try:
            html = urllib.request.urlopen(url=k)
            html = html.read()
            htmlfile = html.decode('utf-8')
        #need to make exceptions for 404
        except Exception as e:
            print(str(e))
        else:
            print("made it past try block")
            singlesoup = BeautifulSoup(htmlfile, 'html.parser')
            soup.append(singlesoup)
            print(soup("context"))
            break
    #textfile.close()
    return soup

# %%
rawTESThtmltext = getsourcetext(sourceurl) #only displays one iteration of appending the soup
# Out:
# 0
# HTTP Error 404: Not Found
# 1
# made it past try block
# []

# %% [markdown]
# The raw html text has too much info like advertisements, pictures, etc. Need to clean the data before getting text. Not sure best way how to yet

# %%
rawhtmltext = getsourcetext(sourceurl) #creates a beautiful soup object that has all of the text from sources in the series
cleanhtmltext = rawhtmltext.get_text(strip=True) #gets all of the written words out as a sting
cleantxtfile = open("just readable text", "w", encoding = "utf-8") #creates a file
cleantxtfile.write(cleanhtmltext) #adds this string to the file
cleantxtfile.close() #closes file
# Out:
# 0
# HTTP Error 404: Not Found
# 1
# made it past try block
# 2
# The read operation timed out
# 3
# HTTP Error 404: Not Found
# 4
# made it past try block
# 5
# HTTP Error 404: Not Found
# 6
# made it past try block
# 7
# made it past try block
# 8
# made it past try block
# 9
# made it past try block
# 10
# made it past try block
# 11
# HTTP Error 404: Not Found
# 12
# made it past try block
# 13
# made it past try block
# 14
# made it past try block
# 15
# made it past try block
# 16
# HTTP Error 404: Not Found
# 17
# HTTP Error 404: Not Found
# 18
# made it past try block
# 19
# HTTP Error 404: Page Not Found
# 20
# made it past try block
# 21
# made it past try block
# 22
# made it past try block
# 23
# HTTP Error 404: Not Found
# 24
# HTTP Error 410: Gone
# 25
# made it past try block
# 26
# HTTP Error 404: Not Found
# 27
# made it past try block
# 28
# made it past try block
# 29
# made it past try block
# 30
# HTTP Error 404: Not Found
# 31
# made it past try block
# 32
# ...

# %% [markdown]
# Beginning the NLP Analysis to Explore The Sources

# %%
import nltk
from nltk.corpus import stopwords
stopwords = nltk.corpus.stopwords.words('english')
#needs to have stop words removed
frequentmswords = FreqDisq(cleanhtmltext)
freqwordcombo = cleanhtmltext.collocations()
keywords = frequentmswords.most_common(10)
killdata = cleanhtmltext.concordance("kill"), cleanhtmltext.similar("kill")
deathdata = cleanhtmltext.concordance("death"), cleanhtmltext.similar("death")
gundata = cleanhtmltext.concordance("gun"), cleanhtmltext.similar("gun")
cleanhtmltext.dispersionplot([keywords])
